# %%
# !nvidia-smi
# Out:
# Fri Oct 13 23:46:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla T4            Off  | 00000000:00:05.0 Off |                    0 |
# | N/A   41C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 15.6 GB RAM, 5016.7/8062.4 GB disk)

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NJpzXwEKxX8jfOlAtF68")
project = rf.workspace("wei-guo").project("gwhd2021")
dataset = project.version(3).download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.7-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.1 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.0 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.9 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from roboflow) (9.5.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.15.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.15)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (6.0)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (4.40.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->roboflow) (3.1.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from supervision->roboflow) (1.11.2)
# Installing collected packages: pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
#       Successfully uninstalled opencv-python-headless-4.8.0.76
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pytoolconfig 1.2.5 requires packaging>=22.0, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.3.1 requires scipy<1.11,>=1.4.1, but you have scipy 1.11.2 which is incompatible.
# Successfully installed certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 roboflow-1.1.7 supervision-0.15.0
# A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.198, to fix: `pip install ultralytics==8.0.134`
# Downloading Dataset Version Zip in GWHD2021-3 to yolov8:: 100%|██████████| 1246623/1246623 [00:23<00:00, 53966.23it/s]
# Extracting Dataset Version Zip to GWHD2021-3 in yolov8:: 100%|██████████| 13040/13040 [00:05<00:00, 2340.02it/s]

# %%
import yaml

# Define the path to your data.yaml file
data_yaml_path = '/kaggle/working/GWHD2021-3/data.yaml'  # Replace with the actual path

# Read and parse the data.yaml file
with open(data_yaml_path, 'r') as file:
    data = yaml.load(file, Loader=yaml.FullLoader)

# Modify the paths in the 'data' dictionary
data['test'] = '/kaggle/working/GWHD2021-3/test'
data['train'] = '/kaggle/working/GWHD2021-3/train'
data['val'] = '/kaggle/working/GWHD2021-3/valid'

# Write the modified data back to the data.yaml file
with open(data_yaml_path, 'w') as file:
    yaml.dump(data, file)

# Print the updated data.yaml
print(data)
# Out:
# {'names': ['whd'], 'nc': 1, 'roboflow': {'license': 'MIT', 'project': 'gwhd2021', 'url': 'https://universe.roboflow.com/wei-guo/gwhd2021/dataset/3', 'version': 3, 'workspace': 'wei-guo'}, 'test': '/kaggle/working/GWHD2021-3/test', 'train': '/kaggle/working/GWHD2021-3/train', 'val': '/kaggle/working/GWHD2021-3/valid'}

# %%
# !yolo task=detect mode=train model=yolov8l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch_size=16 lr=0.01 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt to 'yolov8l.pt'...
# 100%|███████████████████████████████████████| 83.7M/83.7M [00:00<00:00, 224MB/s]
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# engine/trainer: task=detect, mode=train, model=yolov8l.pt, data=/kaggle/working/GWHD2021-3/data.yaml, epochs=100, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00,
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.877      0.932      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      12.4G       1.36      0.578      1.185        862        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.879      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100        12G      1.353     0.5751      1.178        875        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.879      0.932      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      12.9G      1.349     0.5738       1.18        738        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916       0.88      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      12.5G      1.352      0.571      1.179        796        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.879      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      11.7G      1.344       0.57      1.174       1040        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.917      0.879      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      12.6G      1.339     0.5626      1.172       1152        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.918      0.879      0.933       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      11.5G      1.342     0.5651      1.176        828        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.917      0.877      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      13.4G      1.338     0.5651      1.174        659        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915       0.88      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      12.6G      1.334     0.5609       1.17        833        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.919       0.88      0.933       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      12.7G      1.328      0.557      1.172        791        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.917      0.879      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      12.4G      1.328     0.5574      1.167       1003        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.917       0.88      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      12.8G      1.329      0.556      1.169        851        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.881      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      13.2G       1.33     0.5551      1.174        863        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.881      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      12.4G      1.321     0.5512      1.171       1041        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.882      0.933      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      12.5G      1.325     0.5508       1.17       1004        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.879      0.932      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      10.9G      1.313     0.5465      1.166        817        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.881      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      12.3G      1.313     0.5456      1.165       1045        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.881      0.932      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      12.7G      1.311     0.5414      1.162        746        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.881      0.932      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      12.7G      1.307     0.5422      1.161       1135        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.882      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      11.8G      1.307     0.5399      1.156       1049        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.882      0.932      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      12.6G      1.301     0.5375      1.157        841        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.881      0.932      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      13.9G      1.301     0.5362      1.158        964        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.882      0.932      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      12.9G      1.301      0.536      1.154       1171        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.883      0.933      0.556
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      11.8G      1.303      0.523        1.2        515        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.882      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      11.6G      1.291     0.5199      1.193        653        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.914      0.881      0.932      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      11.5G      1.286     0.5134       1.19        661        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.882      0.932      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      11.6G      1.283     0.5128       1.19        582        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.917      0.882      0.933      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      11.1G       1.28     0.5089      1.186        588        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.882      0.932      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      11.3G      1.275     0.5065      1.186        546        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.883      0.933      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      10.9G      1.275     0.5049      1.186        547        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.882      0.932      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      11.7G       1.27     0.5043      1.185        613        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.881      0.932      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      11.3G      1.273     0.5052       1.19        811        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.916      0.883      0.932      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      11.6G      1.268     0.5013      1.184        541        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.915      0.883      0.932      0.555
#
# 100 epochs completed in 8.336 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 87.7MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 87.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients, 164.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1303      55553      0.918      0.879      0.934       0.56
# Speed: 0.4ms preprocess, 17.5ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo task=detect mode=val model=/kaggle/working/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
Image(filename=f'/kaggle/working/runs/detect/train/results.png', width=600)

# %%
# !yolo task=detect mode=predict model=/kaggle/working/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True

# %%
Image(filename=f'/kaggle/working/runs/detect/train/confusion_matrix.png', width=600)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/kaggle/working/runs/detect/predict/*.jpg')[:10]:
      display(Image(filename=image_path, width=600))
      print("\n")
